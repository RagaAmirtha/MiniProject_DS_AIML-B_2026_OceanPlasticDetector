# %%
pip install tensorflow
# Out:
# ...
#    ---------------------------------------- 0.0/351.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/351.2 MB ? eta -:--:--
#    ---------------------------------------- 0.3/351.2 MB ? eta -:--:--
#    ---------------------------------------- 0.8/351.2 MB 2.2 MB/s eta 0:02:38
#    ---------------------------------------- 1.6/351.2 MB 3.2 MB/s eta 0:01:50
#    ---------------------------------------- 1.8/351.2 MB 2.4 MB/s eta 0:02:24
#    ---------------------------------------- 4.2/351.2 MB 4.5 MB/s eta 0:01:17
#     --------------------------------------- 6.0/351.2 MB 5.4 MB/s eta 0:01:04
#     --------------------------------------- 6.8/351.2 MB 5.7 MB/s eta 0:01:01
#     --------------------------------------- 8.1/351.2 MB 5.5 MB/s eta 0:01:02
#    - -------------------------------------- 9.7/351.2 MB 5.5 MB/s eta 0:01:03
#    - -------------------------------------- 10.5/351.2 MB 5.5 MB/s eta 0:01:02
# ...

# %%
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
dataset_path = r"D:\dataset\raw_data"
train_path = os.path.join(dataset_path, "train")
test_path = os.path.join(dataset_path, "test")

print("Train path:", train_path)
print("Test path:", test_path)
print("Train folders:", os.listdir(train_path))
print("Test folders:", os.listdir(test_path))
# Out:
# Train path: D:\dataset\raw_data\train
# Test path: D:\dataset\raw_data\test
# Train folders: ['no-plastic', 'plastic']
# Test folders: ['no-plastic', 'plastic']

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

test_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(
    train_path,
    target_size=(224, 224),
    batch_size=32,
    class_mode='binary',
    subset='training',
    shuffle=True
)
# Out:
# Found 1376 images belonging to 2 classes.

# %%
val_generator = train_datagen.flow_from_directory(
    train_path,
    target_size=(224, 224),
    batch_size=32,
    class_mode='binary',
    subset='validation',
    shuffle=True
)
# Out:
# Found 344 images belonging to 2 classes.

# %%
test_generator = test_datagen.flow_from_directory(
    test_path,
    target_size=(224, 224),
    batch_size=32,
    class_mode='binary',
    shuffle=False
)
# Out:
# Found 430 images belonging to 2 classes.

# %%
print("Class indices:", train_generator.class_indices)
print("Training samples:", train_generator.samples)
print("Validation samples:", val_generator.samples)
print("Test samples:", test_generator.samples)
# Out:
# Class indices: {'no-plastic': 0, 'plastic': 1}
# Training samples: 1376
# Validation samples: 344
# Test samples: 430

# %% [markdown]
# ## Observation: Preprocessing
# All images are resized to 224 × 224 pixels and normalized to the range [0, 1].
# An 80:20 split is used for training and validation from the training folder.
# The test set is loaded separately for final model evaluation.
